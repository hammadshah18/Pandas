# %% [markdown]
# <h1>Creating DataFrames</h1>

# %%
import numpy as np
import pandas as pd
data=[[12,34,56,],[23,56,90],[98,54,89]]
s=pd.DataFrame(data,columns=['iq','Marks','package'])   # create first dataset with 2d List
print(s)
# Out:
#    iq  Marks  package
# 0  12     34       56
# 1  23     56       90
# 2  98     54       89

# %%
#creating dataframes with the help of dictionary
det={ 'IQ':[12,13,14],

        'Marks':[56,23,78],
     'Package':[26,32,81]}
re=pd.DataFrame(det)
print(re)
# Out:
#    IQ  Marks  Package
# 0  12     56       26
# 1  13     23       32
# 2  14     78       81

# %%
mov=pd.read_csv('movies.csv')

# %%
#creating dataFrame with csv file 
a=pd.read_csv('ipl-matches.csv')
print(a)
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
a.plot(kind='bar')
# Out:
# <Axes: >

# %%
pd.read_csv('ipl-matches.csv')
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# <h1>DataFrames Attributes and Method</h1>

# %%
a.info() # it will tell null values of every col
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
a.sample(2)
# Out:
#          ID     City        Date   Season MatchNumber                Team1  \
# 831  419110  Chennai  2010-03-14  2009/10           5  Chennai Super Kings
# 523  733985    Delhi  2014-05-07     2014          28     Delhi Daredevils
#
#                      Team2                            Venue        TossWinner  \
# 831        Deccan Chargers  MA Chidambaram Stadium, Chepauk   Deccan Chargers
# 523  Kolkata Knight Riders                 Feroz Shah Kotla  Delhi Daredevils
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 831          bat         N        Deccan Chargers     Runs    31.0    NaN
# 523          bat         N  Kolkata Knight Riders  Wickets     8.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 831      WPUJC Vaas  ['M Vijay', 'ML Hayden', 'SK Raina', 'S Badrin...
# 523       G Gambhir  ['Q de Kock', 'M Vijay', 'KP Pietersen', 'KD K...
#
# ...

# %%
a.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
a.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
a.isnull()              #tell missig values present or not
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
a.shape # it will tell all row and col
# Out:
# (950, 20)

# %%
a.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
a.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
a.describe() # it will provide all mathematical summmary on numeric values
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
mov.duplicated().sum() #it will tell how many duplicated rows
# Out:
# 0

# %%
mov.isnull().sum() # it will missing values of every columns and calculate how many are present
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#creating dataframes with the help of dictionary
det={ 'IQ':[12,13,14,0,0],

        'Marks':[56,23,78,0,0],
     'Package':[26,32,81,0,0]}
pd.DataFrame(det)
# Out:
#    IQ  Marks  Package
# 0  12     56       26
# 1  13     23       32
# 2  14     78       81
# 3   0      0        0
# 4   0      0        0

# %%
re.duplicated().sum()
# Out:
# 0

# %%
re.rename(columns={'Marks':'score','Package':'lpa'},inplace = True)
print(re)
# Out:
#    IQ  score  lpa
# 0  12     56   26
# 1  13     23   32
# 2  14     78   81

# %%
import pandas as pd

# Original DataFrame
data = [[12, 34, 56], [23, 56, 90], [98, 54, 89]]
df = pd.DataFrame(data, columns=['iq', 'Marks', 'package'])

# Rename columns with inplace=True
df.rename(columns={'iq': 'IQ', 'Marks': 'Score'}, inplace=True)

# Check the updated DataFrame
print(df)
# Out:
#    IQ  Score  package
# 0  12     34       56
# 1  23     56       90
# 2  98     54       89

# %%
a.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
a.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %% [markdown]
# <h1>Mathematical Function </h1>

# %%
a.sum
# Out:
# <bound method DataFrame.sum of           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# ...

# %%
s.sum(axis=0)
# Out:
# iq         133
# Marks      144
# package    235
# dtype: int64

# %%
s.mean(axis=0)
# Out:
# iq         44.333333
# Marks      48.000000
# package    78.333333
# dtype: float64

# %% [markdown]
# <h1>Fecthing columns</h1>

# %%
a['SuperOver'] # fecthing single col from dataframe
# Out:
# 0      N
# 1      N
# 2      N
# 3      N
# 4      N
#       ..
# 945    N
# 946    N
# 947    N
# 948    N
# 949    N
# Name: SuperOver, Length: 950, dtype: object

# %%
a[['Date','MatchNumber','Team1','Team2','WinningTeam']].head()
# Out:
#          Date  MatchNumber                        Team1                 Team2  \
# 0  2022-05-29        Final             Rajasthan Royals        Gujarat Titans
# 1  2022-05-27  Qualifier 2  Royal Challengers Bangalore      Rajasthan Royals
# 2  2022-05-25   Eliminator  Royal Challengers Bangalore  Lucknow Super Giants
# 3  2022-05-24  Qualifier 1             Rajasthan Royals        Gujarat Titans
# 4  2022-05-22           70          Sunrisers Hyderabad          Punjab Kings
#
#                    WinningTeam
# 0               Gujarat Titans
# 1             Rajasthan Royals
# 2  Royal Challengers Bangalore
# 3               Gujarat Titans
# 4                 Punjab Kings

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <h1>fetching rows</h1>

# %%
t=a.iloc[0:5]

# %%
t
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
#fancing indexing
a.iloc[[0,3,9,5,10]]
# Out:
#          ID         City        Date Season  MatchNumber                Team1  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final     Rajasthan Royals
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1     Rajasthan Royals
# 9   1304111       Mumbai  2022-05-17   2022           65  Sunrisers Hyderabad
# 5   1304115       Mumbai  2022-05-21   2022           69       Delhi Capitals
# 10  1304110  Navi Mumbai  2022-05-16   2022           64       Delhi Capitals
#
#              Team2                               Venue        TossWinner  \
# 0   Gujarat Titans    Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 3   Gujarat Titans               Eden Gardens, Kolkata    Gujarat Titans
# 9   Mumbai Indians            Wankhede Stadium, Mumbai    Mumbai Indians
# 5   Mumbai Indians            Wankhede Stadium, Mumbai    Mumbai Indians
# 10    Punjab Kings  Dr DY Patil Sports Academy, Mumbai      Punjab Kings
#
# ...

# %%
import numpy as np
import pandas as pd
analysis=pd.DataFrame({'Name':['Hammad','Ali','jahangeer','kamran','shah','Aslam'],
                      
                      
                      
                      'runs':[12,34,45,90,36,120],
                      'style':['left Handed batsmen','right handed batsmen','right handed batsmen','right handed batsmen','right handed batsmen','right handed batsmen'],
                     })
print(analysis)
# Out:
#         Name  runs                 style
# 0     Hammad    12   left Handed batsmen
# 1        Ali    34  right handed batsmen
# 2  jahangeer    45  right handed batsmen
# 3     kamran    90  right handed batsmen
# 4       shah    36  right handed batsmen
# 5      Aslam   120  right handed batsmen

# %%
type(analysis)
# Out:
# pandas.core.frame.DataFrame

# %%
analysis.iloc[[0,3,5]]
# Out:
#      Name  runs                 style
# 0  Hammad    12   left Handed batsmen
# 3  kamran    90  right handed batsmen
# 5   Aslam   120  right handed batsmen

# %%
analysis
# Out:
#         Name  runs                 style
# 0     Hammad    12   left Handed batsmen
# 1        Ali    34  right handed batsmen
# 2  jahangeer    45  right handed batsmen
# 3     kamran    90  right handed batsmen
# 4       shah    36  right handed batsmen
# 5      Aslam   120  right handed batsmen

# %%
analysis.loc[0:5]
# Out:
#         Name  runs                 style
# 0     Hammad    12   left Handed batsmen
# 1        Ali    34  right handed batsmen
# 2  jahangeer    45  right handed batsmen
# 3     kamran    90  right handed batsmen
# 4       shah    36  right handed batsmen
# 5      Aslam   120  right handed batsmen

# %%
analysis.set_index('Name',inplace=True)
print(analysis.loc['Hammad'])
# Out:
# runs                      12
# style    left Handed batsmen
# Name: Hammad, dtype: object

# %%
analysis
# Out:
#            runs                 style
# Name
# Hammad       12   left Handed batsmen
# Ali          34  right handed batsmen
# jahangeer    45  right handed batsmen
# kamran       90  right handed batsmen
# shah         36  right handed batsmen
# Aslam       120  right handed batsmen

# %% [markdown]
# <h1>Filtering DataFrame</h1>

# %%
a
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# <h1>finding IPL winner teams every year</h1>

# %%
match=a['MatchNumber']=='Final'

# %%
winner=a[match]
winner[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
a[a['MatchNumber']=='Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %% [markdown]
# <h1>Finding super occured
# </h1>

# %%
a
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
a[a['SuperOver']=='Y'].count
# Out:
# <bound method DataFrame.count of           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
a[a['SuperOver']=='Y'].info
# Out:
# <bound method DataFrame.info of           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
a[a['SuperOver']=='Y'].describe
# Out:
# <bound method NDFrame.describe of           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
a[a['SuperOver']=='Y'].shape[0] #it will tell only total matches
# Out:
# 14

# %% [markdown]
# <h1>How Many matches csk  Won in kolkata</h1>

# %%
a.iloc[[0,2]]
# Out:
#         ID       City        Date Season MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final
# 2  1312198    Kolkata  2022-05-25   2022  Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
a[(a['City']=='Kolkata') & (a['WinningTeam']=='Chennai Super Kings')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
a
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# <h1>Findig toss winner also a match Winner</h1>

# %%
(a[a['TossWinner']==a['WinningTeam']].shape[0]/a.shape[0])*100 # finding percentage of toss winner also a match winner
# Out:
# 51.473684210526315

# %% [markdown]
# <h1>Movies raTING HIGHER THAN 8 and votes>1000</h1>

# %%
mov.head(4)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
mov[(mov['imdb_rating'] > 8) & (mov['imdb_votes'] > 1000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 53                    Section 375   tt8144834
# 58              Ghost (2019 film)   tt9378950
# 59               Bala (2019 film)   tt9420648
# 62                 Saand Ki Aankh   tt8108206
# 64                    Ujda Chaman  tt11046300
# 84                      Mukkabaaz   tt7180544
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 192      Sachin: A Billion Dreams   tt4640206
# 279            Nil Battey Sannata   tt5005684
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# ...

# %%
mov[(mov['imdb_rating'] > 8) & (mov['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
mask1=mov['genres'].str.split('|').apply(lambda x : 'Action' in x)
mask2=mov['imdb_rating']>8
mov[mask1 & mask2]
# Out:
#                           title_x    imdb_id  \
# 0        Uri: The Surgical Strike  tt8291224
# 41           Family of Thakurganj  tt8897986
# 84                      Mukkabaaz  tt7180544
# 219              Raag Desh (film)  tt6080746
# 354                 Dangal (film)  tt5074352
# 536                 Haider (film)  tt3390572
# 589                  Vishwaroopam  tt2199711
# 668       Paan Singh Tomar (film)  tt1620933
# 693            Gangs of Wasseypur  tt1954470
# 694   Gangs of Wasseypur – Part 2  tt1954470
# 1058     Black Friday (2007 film)  tt0400234
# 1188           Omkara (2006 film)  tt0488414
# 1554   The Legend of Bhagat Singh  tt0319736
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 84    https://upload.wikimedia.org/wikipedia/en/thum...
# 219   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
mas1=mov['genres'].str.contains('Action')
mas2=mov['imdb_rating']>8
mov[mas1 & mas2]
# Out:
#                           title_x    imdb_id  \
# 0        Uri: The Surgical Strike  tt8291224
# 41           Family of Thakurganj  tt8897986
# 84                      Mukkabaaz  tt7180544
# 219              Raag Desh (film)  tt6080746
# 354                 Dangal (film)  tt5074352
# 536                 Haider (film)  tt3390572
# 589                  Vishwaroopam  tt2199711
# 668       Paan Singh Tomar (film)  tt1620933
# 693            Gangs of Wasseypur  tt1954470
# 694   Gangs of Wasseypur – Part 2  tt1954470
# 1058     Black Friday (2007 film)  tt0400234
# 1188           Omkara (2006 film)  tt0488414
# 1554   The Legend of Bhagat Singh  tt0319736
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 84    https://upload.wikimedia.org/wikipedia/en/thum...
# 219   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# <h1>Adding new col</h1>

# %%
mov['Country']='India'
mov.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# mov.dropna('actors',inplace=True)  

mov.dropna(subset=['actors'], inplace=True)

# %%
mov['Lead actor']=mov['actors'].str.split('|').apply(lambda x : x[0])
mov.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
mov.shape[0]
# Out:
# 1624

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
a['ID']=a['ID'].astype('int32')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
a['Team1']=a['Team1'].astype('category')

# %%
a['Team2']=a['Team2'].astype('category')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
a['Venue']=a['Venue'].astype('category')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    category
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
